# %%
#ingest the data 
import pandas as pd
import os
os.chdir("d:\\Data Science Projects\\fsdsendtoend\\notebooks\\data")

# %%
pwd()
# Out:
# 'd:\\Data Science Projects\\fsdsendtoend\\notebooks\\data'

# %%
df = pd.read_csv(r"D:\Data Science Projects\fsdsendtoend\notebooks\data\gemstone.csv")

# %%
df
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %% [markdown]
# <h4>CARAT</h4>: The term "carat" is a unit of measurement used for gemstones, including diamonds. It is a measure of a diamond's weight and is equivalent to 200 milligrams. The weight of a diamond is measured in carats. One carat is equivalent to 200 milligrams or 0.2 grams. The term "carat" is often abbreviated as "ct." For larger diamonds, you might also hear about points. A point is a unit of measure commonly used for diamonds less than one carat. There are 100 points in a carat, so a 0.75-carat diamond, for example, would be referred to as a "seventy-five pointer."
#
#
# <h4>cut</h4>:The "cut" of a diamond refers to how well the diamond has been shaped and faceted. It is one of the crucial factors that contribute to a diamond's overall appearance and beauty. The cut affects how the diamond reflects light and, consequently, how it sparkles. A well-cut diamond will have optimal proportions and symmetry, allowing light to enter and reflect in a way that enhances its brilliance.
# The cut is often graded on a scale ranging from "Excellent" to "Poor." The Gemological Institute of America (GIA) uses the following cut grades:
# Excellent,
# Very Good,
# Good,
# Fair,
# Poor
#
#
# <h4>color</h4>: The color of a diamond refers to the presence or absence of color in a white diamond. The Gemological Institute of America (GIA) uses a grading scale from D to Z to assess the color of diamonds. This scale is divided into the following categories:
#
# 1. **D to F (Colorless):** Diamonds in this range are considered colorless and are highly valued for their rarity. They appear icy white and allow the most light to pass through.
#
# 2. **G to J (Near Colorless):** Diamonds in this range have a slightly detectable color that is usually not visible to the untrained eye. They offer a good balance between quality and value.
#
# 3. **K to M (Faint):** Faint yellow or brown hues are more noticeable in diamonds in this range, especially when viewed from the side. They are often a more budget-friendly option.
#
# 4. **N to R (Very Light):** Diamonds in this range exhibit noticeable color and are typically less expensive than higher-grade diamonds. They may appear more yellow or brown.
#
# 5. **S to Z (Light):** Diamonds in this range have a more pronounced yellow or brown color, and the color is easily visible. They are generally not as highly valued as diamonds with less color.
#
# It's important to note that some diamonds, known as fancy colored diamonds, come in colors other than white. These can include shades of blue, pink, yellow, and more. However, these diamonds are graded on a different scale based on the intensity and hue of their color rather than being compared to the absence of color, as is the case with white diamonds.
#
# <h4>Clarity</h4>Clarity is one of the Four Cs used to assess the quality of a diamond, and it refers to the presence of internal characteristics (inclusions) and external blemishes (blemishes). These characteristics are often referred to as "clarity characteristics." The Gemological Institute of America (GIA) provides a clarity grading scale:
#
# 1. **Flawless (FL) and Internally Flawless (IF):** No inclusions or blemishes visible under 10x magnification. FL diamonds have no internal or external flaws, while IF diamonds have no internal flaws but may have minor surface blemishes.
#
# 2. **Very, Very Slightly Included (VVS1 and VVS2):** Inclusions are extremely difficult to see under 10x magnification. VVS diamonds have minute inclusions that are extremely difficult to detect.
#
# 3. **Very Slightly Included (VS1 and VS2):** Inclusions are minor and not easily visible under 10x magnification. VS diamonds have slight inclusions that are visible only to an experienced grader.
#
# 4. **Slightly Included (SI1 and SI2):** Inclusions are noticeable under 10x magnification and may be visible to the naked eye. SI diamonds have noticeable inclusions that may affect transparency and brilliance.
#
# 5. **Included (I1, I2, and I3):** Inclusions are visible to the naked eye. I diamonds have obvious inclusions that can impact the diamond's appearance and durability.
#
# When choosing a diamond, it's crucial to find a balance between clarity and budget. Diamonds with higher clarity grades (closer to Flawless) are rarer and, therefore, more expensive. However, many diamonds in the VS and SI range are considered "eye-clean," meaning that any inclusions are not visible to the naked eye.
#
# The choice of clarity grade depends on personal preferences, the size of the diamond, and the setting. Larger diamonds may show inclusions more readily, so you might prioritize higher clarity for larger stones.
#
#
# <h4>Depth and table</h4> are two important aspects of a diamond's cut that contribute to its overall appearance. These factors are measured as percentages and are part of the diamond cut grading.
#
# 1. **Depth:**
#    - **Definition:** The depth of a diamond is the measurement from the table (top) to the culet (bottom). It is expressed as a percentage of the diamond's overall diameter.
#    - **Importance:** Proper depth is crucial for a diamond's brilliance and sparkle. If a diamond is too shallow or too deep, light can escape through the sides or bottom rather than reflecting back to the observer, affecting its overall beauty.
#
# 2. **Table:**
#    - **Definition:** The table is the flat, top surface of the diamond. It is measured as a percentage of the diamond's overall diameter.
#    - **Importance:** The size of the table affects how much light is returned to the observer. An overly large table may cause a diamond to appear glassy, while an extremely small table might impact brilliance. An ideal table size depends on the overall cut and proportions of the diamond.
#
# The combination of depth and table percentages, along with other factors like crown angle and pavilion angle, influences the diamond's cut grade. A well-cut diamond will have balanced proportions, allowing light to interact optimally with the diamond for maximum brilliance.
#
# When evaluating a diamond, it's advisable to consider a range of depth (usually between 58% and 64%) and table (between 53% and 64%) percentages, depending on personal preferences and the desired appearance of the diamond.
#
#
# <h4>"x," "y," and "z"</h4>
# In the context of diamonds, the terms "x," "y," and "z" typically refer to the measurements of the diamond in three dimensions. These measurements are used to describe the physical size and shape of the diamond.
#
# 1. **X:** The X measurement is the length of the diamond from side to side.
#
# 2. **Y:** The Y measurement is the width of the diamond, measuring from front to back.
#
# 3. **Z:** The Z measurement is the depth of the diamond, measuring from the table (top) to the culet (bottom).
#
# These measurements, along with the diamond's overall weight (carat), are essential in determining the diamond's proportions and can impact its appearance and visual appeal. The combination of these measurements, along with factors like table percentage, depth percentage, and angles, contributes to the overall cut grade of the diamond.
#
# When purchasing a diamond, it's important to consider not only carat weight but also the proportions and cut quality, as these factors play a significant role in the diamond's brilliance and sparkle. A well-proportioned diamond with an excellent cut is likely to exhibit better light performance and overall visual appeal.

# %%
# 5 random sample from the data

df.sample(5)
# Out:
#             id  carat      cut color clarity  depth  table     x     y     z  \
# 182410  182410   2.03    Ideal     H     SI1   62.5   56.0  8.10  8.05  5.05
# 133917  133917   0.56    Ideal     F     SI2   60.4   56.0  5.40  5.36  3.25
# 65410    65410   0.32  Premium     H     VS1   60.2   58.0  4.44  4.48  2.70
# 23928    23928   1.53    Ideal     E     SI1   61.4   57.0  7.39  7.45  4.56
# 47822    47822   2.32    Ideal     J     VS2   62.2   57.0  8.57  8.43  5.27
#
#         price
# 182410  18509
# 133917   1292
# 65410     544
# 23928   12717
# 47822   16716

# %%
df.isna().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.drop(columns='id',inplace=True)
